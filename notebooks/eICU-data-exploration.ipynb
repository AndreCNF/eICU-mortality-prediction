# %% [markdown]
# # eICU Data Exploration
# ---
#
# Exploring the eICU dataset from MIT with the data from over 139k patients collected in the US.
#
# The eICU Collaborative Research Database is a multi-center intensive care unit (ICU) database with high granularity data for over 200,000 admissions to ICUs monitored by eICU Programs across the United States. The database is deidentified, and includes vital sign measurements, care plan documentation, severity of illness measures, diagnosis information, treatment information, and more.

# %% [markdown]
# ## Importing the necessary packages

# %%
import pandas as pd              # Pandas to handle the data in dataframes
import re                        # re to do regex searches in string data
import plotly                    # Plotly for interactive and pretty plots
import plotly.graph_objs as go
from datetime import datetime    # datetime to use proper date and time formats
import os                        # os handles directory/workspace changes
from glob import glob            # Find files by name
import yaml                      # Save and load YAML files
import numpy as np               # NumPy to handle numeric and NaN operations
from tqdm import tqdm_notebook   # tqdm allows to track code execution progress
import numbers                   # numbers allows to check if data is numeric
import torch                     # PyTorch to create and apply deep learning models
from torch.utils.data.sampler import SubsetRandomSampler
import data_utils as du          # Data science and machine learning relevant methods

# %%
import plotly.io as pio
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %% [markdown]
# Use Plotly in dark mode:

# %%
pio.templates.default = 'plotly_dark'

# %%
# Change to parent directory (presumably "Documents")
os.chdir("../../..")
# Path to the CSV dataset files
data_path = 'data/'

# %%
du.set_pandas_library(lib='pandas')

# %% [markdown]
# Allow pandas to show more columns:

# %%
pd.set_option('display.max_columns', 3000)
pd.set_option('display.max_rows', 3000)

# %% [markdown]
# Set the random seed for reproducibility:

# %%
du.set_random_seed(42)

# %% [markdown]
# ## Initializing variables

# %%
stream_dtypes = open(f'{data_path}eICU_dtype_dict.yml', 'r')

# %%
dtype_dict = yaml.load(stream_dtypes, Loader=yaml.FullLoader)
dtype_dict
# Out:
# {'CAD': 'UInt8',
#  'Cancer': 'UInt8',
#  'Ethanol_Use_heavy': 'UInt8',
#  'Ethanol_Use_hx_delirium_tremens': 'UInt8',
#  'Ethanol_Use_hx_delirium_tremens_and_withdrawal_seizures': 'UInt8',
#  'Ethanol_Use_hx_withdrawal_seizures': 'UInt8',
#  'Ethanol_Use_moderate_(daily)': 'UInt8',
#  'Ethanol_Use_moderate_(not_daily)': 'UInt8',
#  'Ethanol_Use_none': 'UInt8',
#  'Ethanol_Use_rare': 'UInt8',
#  'Smoking_Status_20_-_40_pack_years_-_remote_hx_of_smoking': 'UInt8',
#  'Smoking_Status_20_-_40_pack_years_-_still_smoking': 'UInt8',
#  'Smoking_Status_<_20_pack_years_-_remote_hx_of_smoking': 'UInt8',
#  'Smoking_Status_<_20_pack_years_-_still_smoking': 'UInt8',
#  'Smoking_Status_>_40_pack_years_-_remote_hx_of_smoking': 'UInt8',
#  'Smoking_Status_>_40_pack_years_-_still_smoking': 'UInt8',
#  'Smoking_Status_denies_smoking': 'UInt8',
#  'Smoking_Status_smokes_cigar_or_pipe': 'UInt8',
#  'Smoking_Status_uses_smokeless_tobacco': 'UInt8',
#  'admissionheight': 'float32',
#  'admissionweight': 'float32',
#  'age': 'float32',
#  'bodyweight_(kg)': 'float32',
#  'cardiacinput': 'float32',
#  'cardiacoutput': 'float32',
#  'crystalloids_intake': 'float32',
#  'cvp': 'float32',
#  'death_ts': 'Int32',
#  'diagnosis_detailed_3_ARDS': 'UInt8',
#  'diagnosis_detailed_3_CABG_<_7days': 'UInt8',
#  'diagnosis_detailed_3_COPD': 'UInt8',
#  'diagnosis_detailed_3_COPD|moderate': 'UInt8',
#  'diagnosis_detailed_3_COPD|severe': 'UInt8',
#  'diagnosis_detailed_3_DKA': 'UInt8',
#  'diagnosis_detailed_3_DVT': 'UInt8',
#  'diagnosis_detailed_3_ESRD_(end_stage_renal_disease)': 'UInt8',
#  'diagnosis_detailed_3_GI_bleeding': 'UInt8',
#  'diagnosis_detailed_3_GI_obstruction_/_ileus': 'UInt8',
#  'diagnosis_detailed_3_GI_obstruction_/_ileus|small_bowel_obstruction': 'UInt8',
#  'diagnosis_detailed_3_SVT': 'UInt8',
#  'diagnosis_detailed_3_Tracheostomy_performed_during_this_admission_for_ventilatory_support': 'UInt8',
#  'diagnosis_detailed_3_abdominal_pain_/_tenderness': 'UInt8',
#  'diagnosis_detailed_3_acute_COPD_exacerbation': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome|acute_myocardial_infarction_(no_ST_elevation)': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome|acute_myocardial_infarction_(with_ST_elevation)': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome|s/p_PTCA': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome|s/p_PTCA|with_stent_placement': 'UInt8',
#  'diagnosis_detailed_3_acute_coronary_syndrome|unstable_angina': 'UInt8',
#  'diagnosis_detailed_3_acute_on_chronic_respiratory_failure_not_due_to_CHF': 'UInt8',
#  'diagnosis_detailed_3_acute_pulmonary_edema': 'UInt8',
#  'diagnosis_detailed_3_acute_renal_failure': 'UInt8',
#  'diagnosis_detailed_3_acute_renal_failure|acute_tubular_necrosis': 'UInt8',
#  'diagnosis_detailed_3_acute_renal_failure|due_to_hypovolemia/decreased_circulating_volume': 'UInt8',
#  'diagnosis_detailed_3_acute_renal_failure|due_to_rhabdomyolysis': 'UInt8',
#  'diagnosis_detailed_3_acute_renal_failure|due_to_sepsis': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_distress': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|drug_related|residual_general_anesthesia': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|due_to_inability_to_clear_secretions': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|due_to_increased_CO2_production': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|due_to_neurological_process': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|due_to_obstructive_lung_disease': 'UInt8',
#  'diagnosis_detailed_3_acute_respiratory_failure|due_to_pulmonary_infiltrates': 'UInt8',
#  'diagnosis_detailed_3_agitation': 'UInt8',
#  'diagnosis_detailed_3_alcohol_withdrawal': 'UInt8',
#  'diagnosis_detailed_3_anemia': 'UInt8',
#  'diagnosis_detailed_3_anemia|acute_blood_loss_anemia': 'UInt8',
#  'diagnosis_detailed_3_anemia|anemia_of_chronic_disease': 'UInt8',
#  'diagnosis_detailed_3_anemia|anemia_of_critical_illness': 'UInt8',
#  'diagnosis_detailed_3_anemia|multifactorial_anemia': 'UInt8',
#  'diagnosis_detailed_3_anxiety': 'UInt8',
#  'diagnosis_detailed_3_ascites': 'UInt8',
#  'diagnosis_detailed_3_asthma_/_bronchospasm': 'UInt8',
#  'diagnosis_detailed_3_atelectasis/collapse': 'UInt8',
#  'diagnosis_detailed_3_atrial_fibrillation': 'UInt8',
#  'diagnosis_detailed_3_atrial_fibrillation|with_controlled_ventricular_response': 'UInt8',
#  'diagnosis_detailed_3_atrial_fibrillation|with_rapid_ventricular_response': 'UInt8',
#  'diagnosis_detailed_3_atrial_flutter': 'UInt8',
#  'diagnosis_detailed_3_bacteremia': 'UInt8',
#  'diagnosis_detailed_3_bacteremia|gram_postive_coccus': 'UInt8',
#  'diagnosis_detailed_3_bipolar_disorder': 'UInt8',
#  'diagnosis_detailed_3_bone_fracture(s)|ribs': 'UInt8',
#  'diagnosis_detailed_3_bradycardia': 'UInt8',
#  'diagnosis_detailed_3_brain_tumor': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest|initial_rhythm:_asystole': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest|initial_rhythm:_pulseless_electrical_activity': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest|initial_rhythm:_ventricular_fibrillation': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest|witnessed_and_<_15_minutes_CPR': 'UInt8',
#  'diagnosis_detailed_3_cardiac_arrest|witnessed_and_>_15_minutes_CPR': 'UInt8',
#  'diagnosis_detailed_3_cardiogenic_shock': 'UInt8',
#  'diagnosis_detailed_3_cardiomyopathy': 'UInt8',
#  'diagnosis_detailed_3_cellulitis': 'UInt8',
#  'diagnosis_detailed_3_cellulitis|extremity': 'UInt8',
#  'diagnosis_detailed_3_cerebral_subdural_hematoma': 'UInt8',
#  'diagnosis_detailed_3_change_in_mental_status': 'UInt8',
#  'diagnosis_detailed_3_chest_pain': 'UInt8',
#  'diagnosis_detailed_3_chest_pain|r/o_myocardial_ischemia': 'UInt8',
#  'diagnosis_detailed_3_chest_wall_trauma': 'UInt8',
#  'diagnosis_detailed_3_chronic_kidney_disease': 'UInt8',
#  'diagnosis_detailed_3_chronic_kidney_disease|Stage_2_(GFR_60-89)': 'UInt8',
#  'diagnosis_detailed_3_chronic_kidney_disease|Stage_3_(GFR_30-59)': 'UInt8',
#  'diagnosis_detailed_3_chronic_kidney_disease|Stage_4_(GFR_15-29)': 'UInt8',
#  'diagnosis_detailed_3_chronic_renal_insufficiency': 'UInt8',
#  'diagnosis_detailed_3_chronic_respiratory_failure': 'UInt8',
#  'diagnosis_detailed_3_coagulopathy': 'UInt8',
#  'diagnosis_detailed_3_coagulopathy|coumadin_administration': 'UInt8',
#  'diagnosis_detailed_3_coagulopathy|liver_failure': 'UInt8',
#  'diagnosis_detailed_3_colon_CA': 'UInt8',
#  'diagnosis_detailed_3_coma': 'UInt8',
#  'diagnosis_detailed_3_congestive_heart_failure': 'UInt8',
#  'diagnosis_detailed_3_congestive_heart_failure|diastolic': 'UInt8',
#  'diagnosis_detailed_3_constipation': 'UInt8',
#  'diagnosis_detailed_3_coronary_artery_disease': 'UInt8',
#  'diagnosis_detailed_3_coronary_artery_disease|known': 'UInt8',
#  'diagnosis_detailed_3_coronary_artery_disease|s/p_CABG': 'UInt8',
#  'diagnosis_detailed_3_dehydration': 'UInt8',
#  'diagnosis_detailed_3_delirium': 'UInt8',
#  'diagnosis_detailed_3_dementia': 'UInt8',
#  'diagnosis_detailed_3_depressed_level_of_consciousness': 'UInt8',
#  'diagnosis_detailed_3_depression': 'UInt8',
#  'diagnosis_detailed_3_diabetes_mellitus': 'UInt8',
#  'diagnosis_detailed_3_diabetes_mellitus|Type_II': 'UInt8',
#  'diagnosis_detailed_3_diabetes_mellitus|Type_II|controlled': 'UInt8',
#  'diagnosis_detailed_3_diabetes_mellitus|Type_II|uncontrolled': 'UInt8',
#  'diagnosis_detailed_3_diarrhea': 'UInt8',
#  'diagnosis_detailed_3_drug_overdose-_general': 'UInt8',
#  'diagnosis_detailed_3_drug_overdose-_general|suicide_attempt': 'UInt8',
#  'diagnosis_detailed_3_drug_overdose-_general|with_decreased_mental_status': 'UInt8',
#  'diagnosis_detailed_3_drug_withdrawal_syndrome|alcohol': 'UInt8',
#  'diagnosis_detailed_3_dysphagia': 'UInt8',
#  'diagnosis_detailed_3_encephalopathy': 'UInt8',
#  'diagnosis_detailed_3_encephalopathy|hepatic': 'UInt8',
#  'diagnosis_detailed_3_encephalopathy|metabolic': 'UInt8',
#  'diagnosis_detailed_3_encephalopathy|post-anoxic': 'UInt8',
#  'diagnosis_detailed_3_encephalopathy|toxic': 'UInt8',
#  'diagnosis_detailed_3_enteritis|C._difficile_colitis': 'UInt8',
#  'diagnosis_detailed_3_esophagitis|regurgitant': 'UInt8',
#  'diagnosis_detailed_3_failure_to_wean': 'UInt8',
#  'diagnosis_detailed_3_fever': 'UInt8',
#  'diagnosis_detailed_3_headache': 'UInt8',
#  'diagnosis_detailed_3_hematological_effect_of_infection|bandemia': 'UInt8',
#  'diagnosis_detailed_3_hematological_effect_of_infection|leukocytosis': 'UInt8',
#  'diagnosis_detailed_3_hemorrhage': 'UInt8',
#  'diagnosis_detailed_3_hepatic_dysfunction': 'UInt8',
#  'diagnosis_detailed_3_hepatic_dysfunction|acute': 'UInt8',
#  'diagnosis_detailed_3_hepatic_dysfunction|chronic': 'UInt8',
#  'diagnosis_detailed_3_hepatic_dysfunction|with_cirrhosis': 'UInt8',
#  'diagnosis_detailed_3_hepatic_dysfunction|with_cirrhosis|alcoholic': 'UInt8',
#  'diagnosis_detailed_3_hepatic_encephalopathy': 'UInt8',
#  'diagnosis_detailed_3_hepatic_failure': 'UInt8',
#  'diagnosis_detailed_3_hyperbilirubinemia': 'UInt8',
#  'diagnosis_detailed_3_hypercarbia': 'UInt8',
#  'diagnosis_detailed_3_hyperchloremia': 'UInt8',
#  'diagnosis_detailed_3_hyperglycemia': 'UInt8',
#  'diagnosis_detailed_3_hyperglycemia|corticosteroid_related': 'UInt8',
#  'diagnosis_detailed_3_hyperglycemia|stress_related': 'UInt8',
#  'diagnosis_detailed_3_hyperglycemia|suspected': 'UInt8',
#  'diagnosis_detailed_3_hyperkalemia': 'UInt8',
#  'diagnosis_detailed_3_hyperkalemia|severe_(>_6.1_meq/dl)': 'UInt8',
#  'diagnosis_detailed_3_hyperlipidemia': 'UInt8',
#  'diagnosis_detailed_3_hypernatremia': 'UInt8',
#  'diagnosis_detailed_3_hypernatremia|moderate_(146_-_155_meq/dl)': 'UInt8',
#  'diagnosis_detailed_3_hypertension': 'UInt8',
#  'diagnosis_detailed_3_hypertension|controlled': 'UInt8',
#  'diagnosis_detailed_3_hypertension|hypertensive_emergency/urgency': 'UInt8',
#  'diagnosis_detailed_3_hypertension|uncontrolled': 'UInt8',
#  'diagnosis_detailed_3_hypervolemia': 'UInt8',
#  'diagnosis_detailed_3_hypocalcemia': 'UInt8',
#  'diagnosis_detailed_3_hypoglycemia': 'UInt8',
#  'diagnosis_detailed_3_hypokalemia': 'UInt8',
#  'diagnosis_detailed_3_hypokalemia|moderate_(_2.8_-_3.5_meq/dl)': 'UInt8',
#  'diagnosis_detailed_3_hypomagnesemia': 'UInt8',
#  'diagnosis_detailed_3_hyponatremia': 'UInt8',
#  'diagnosis_detailed_3_hyponatremia|moderate_(125_-_135_meq/dl)': 'UInt8',
#  'diagnosis_detailed_3_hyponatremia|severe_(<_125_meq/dl)': 'UInt8',
#  'diagnosis_detailed_3_hypophosphatemia': 'UInt8',
#  'diagnosis_detailed_3_hypotension': 'UInt8',
#  'diagnosis_detailed_3_hypotension_/_pressor_dependent': 'UInt8',
#  'diagnosis_detailed_3_hypothyroidism': 'UInt8',
#  'diagnosis_detailed_3_hypothyroidism|primary': 'UInt8',
#  'diagnosis_detailed_3_hypovolemia': 'UInt8',
#  'diagnosis_detailed_3_hypovolemic_shock': 'UInt8',
#  'diagnosis_detailed_3_hypovolemic_shock|hemorrhagic': 'UInt8',
#  'diagnosis_detailed_3_hypoxemia': 'UInt8',
#  'diagnosis_detailed_3_intracranial_injury': 'UInt8',
#  'diagnosis_detailed_3_intracranial_injury|with_intracerebral_hemorrhage': 'UInt8',
#  'diagnosis_detailed_3_intracranial_injury|with_subarachnoid_hemorrhage': 'UInt8',
#  'diagnosis_detailed_3_intracranial_injury|with_subdural_hematoma': 'UInt8',
#  'diagnosis_detailed_3_leukocytosis': 'UInt8',
#  'diagnosis_detailed_3_lower_GI_bleeding': 'UInt8',
#  'diagnosis_detailed_3_lower_urinary_tract_infection': 'UInt8',
#  'diagnosis_detailed_3_lung_trauma|with_contusion_of_lung': 'UInt8',
#  'diagnosis_detailed_3_metabolic_acidosis': 'UInt8',
#  'diagnosis_detailed_3_metabolic_acidosis|lactic_acidosis': 'UInt8',
#  'diagnosis_detailed_3_nausea': 'UInt8',
#  'diagnosis_detailed_3_nausea|with_vomiting': 'UInt8',
#  'diagnosis_detailed_3_nutritional_deficiency': 'UInt8',
#  'diagnosis_detailed_3_nutritional_deficiency|moderate': 'UInt8',
#  'diagnosis_detailed_3_obesity': 'UInt8',
#  'diagnosis_detailed_3_obesity|morbid': 'UInt8',
#  'diagnosis_detailed_3_obstructive_sleep_apnea': 'UInt8',
#  'diagnosis_detailed_3_obtundation': 'UInt8',
#  'diagnosis_detailed_3_oliguria': 'UInt8',
#  'diagnosis_detailed_3_pain': 'UInt8',
#  'diagnosis_detailed_3_pain|moderate': 'UInt8',
#  'diagnosis_detailed_3_pain|severe': 'UInt8',
#  'diagnosis_detailed_3_pancreatitis': 'UInt8',
#  'diagnosis_detailed_3_pancreatitis|acute': 'UInt8',
#  'diagnosis_detailed_3_pancytopenia': 'UInt8',
#  'diagnosis_detailed_3_peptic_ulcer_disease': 'UInt8',
#  'diagnosis_detailed_3_pericardial_effusion': 'UInt8',
#  'diagnosis_detailed_3_peripheral_vascular_ischemia': 'UInt8',
#  'diagnosis_detailed_3_peritonitis': 'UInt8',
#  'diagnosis_detailed_3_pleural_effusion': 'UInt8',
#  'diagnosis_detailed_3_pleural_effusion|large': 'UInt8',
#  'diagnosis_detailed_3_pleural_effusion|left': 'UInt8',
#  'diagnosis_detailed_3_pleural_effusion|right': 'UInt8',
#  'diagnosis_detailed_3_pneumonia': 'UInt8',
#  'diagnosis_detailed_3_pneumonia|aspiration': 'UInt8',
#  'diagnosis_detailed_3_pneumonia|community-acquired': 'UInt8',
#  'diagnosis_detailed_3_pneumonia|community-acquired|bacterial': 'UInt8',
#  'diagnosis_detailed_3_pneumonia|hospital_acquired_(not_ventilator-associated)': 'UInt8',
#  'diagnosis_detailed_3_pneumonia|ventilator-associated': 'UInt8',
#  'diagnosis_detailed_3_pneumothorax': 'UInt8',
#  'diagnosis_detailed_3_post_craniotomy': 'UInt8',
#  'diagnosis_detailed_3_post_craniotomy|for_hemorrhage': 'UInt8',
#  'diagnosis_detailed_3_post_craniotomy|for_tumor': 'UInt8',
#  'diagnosis_detailed_3_pressure_sore': 'UInt8',
#  'diagnosis_detailed_3_primary_lung_cancer': 'UInt8',
#  'diagnosis_detailed_3_protein-calorie_malnutrition': 'UInt8',
#  'diagnosis_detailed_3_pulmonary_aspiration': 'UInt8',
#  'diagnosis_detailed_3_pulmonary_embolism': 'UInt8',
#  'diagnosis_detailed_3_pulmonary_hypertension': 'UInt8',
#  'diagnosis_detailed_3_respiratory_acidosis': 'UInt8',
#  'diagnosis_detailed_3_respiratory_arrest': 'UInt8',
#  'diagnosis_detailed_3_s/p_CABG_<_7_days': 'UInt8',
#  'diagnosis_detailed_3_s/p_CABG_<_7_days|with_CPB': 'UInt8',
#  'diagnosis_detailed_3_s/p_cartoid_endarterectomy': 'UInt8',
#  'diagnosis_detailed_3_s/p_cholecystectomy': 'UInt8',
#  'diagnosis_detailed_3_s/p_exploratory_laparotomy': 'UInt8',
#  'diagnosis_detailed_3_s/p_surgery_for_intestinal_obstruction': 'UInt8',
#  'diagnosis_detailed_3_schizophrenia': 'UInt8',
#  'diagnosis_detailed_3_sedated': 'UInt8',
#  'diagnosis_detailed_3_seizures': 'UInt8',
#  'diagnosis_detailed_3_seizures|status_epilepticus': 'UInt8',
#  'diagnosis_detailed_3_sepsis': 'UInt8',
#  'diagnosis_detailed_3_sepsis|sepsis_with_multi-organ_dysfunction': 'UInt8',
#  'diagnosis_detailed_3_sepsis|sepsis_with_multi-organ_dysfunction_syndrome': 'UInt8',
#  'diagnosis_detailed_3_sepsis|sepsis_with_single_organ_dysfunction-_acute_renal_failure': 'UInt8',
#  'diagnosis_detailed_3_sepsis|sepsis_with_single_organ_dysfunction-_acute_respiratory_failure': 'UInt8',
#  'diagnosis_detailed_3_sepsis|sepsis_with_single_organ_dysfunction-_circulatory_system_failure': 'UInt8',
#  'diagnosis_detailed_3_sepsis|severe': 'UInt8',
#  'diagnosis_detailed_3_septic_shock': 'UInt8',
#  'diagnosis_detailed_3_septic_shock|cultures_pending': 'UInt8',
#  'diagnosis_detailed_3_signs_and_symptoms_of_sepsis_(SIRS)': 'UInt8',
#  'diagnosis_detailed_3_sinus_tachycardia': 'UInt8',
#  'diagnosis_detailed_3_stroke': 'UInt8',
#  'diagnosis_detailed_3_stroke|hemorrhagic_stroke': 'UInt8',
#  'diagnosis_detailed_3_stroke|hemorrhagic_stroke|subarachnoid_hemorrhage': 'UInt8',
#  'diagnosis_detailed_3_stroke|ischemic_stroke': 'UInt8',
#  'diagnosis_detailed_3_syncope': 'UInt8',
#  'diagnosis_detailed_3_third_spacing': 'UInt8',
#  'diagnosis_detailed_3_thrombocytopenia': 'UInt8',
#  'diagnosis_detailed_3_transaminase_elevation': 'UInt8',
#  'diagnosis_detailed_3_upper_GI_bleeding': 'UInt8',
#  'diagnosis_detailed_3_urinary_tract_infection': 'UInt8',
#  'diagnosis_detailed_3_valve_replacement_<_7days': 'UInt8',
#  'diagnosis_detailed_3_valve_replacement_<_7days|aortic': 'UInt8',
#  'diagnosis_detailed_3_valve_replacement_<_7days|mitral': 'UInt8',
#  'diagnosis_detailed_3_valvular_insufficiency|mitral_valve': 'UInt8',
#  'diagnosis_detailed_3_valvular_stenosis|aortic': 'UInt8',
#  'diagnosis_detailed_3_ventricular_tachycardia': 'UInt8',
#  'diagnosis_detailed_3_viral_hepatitis|hepatitis_C': 'UInt8',
#  'diagnosis_detailed_3_vomiting': 'UInt8',
#  'diagnosis_detailed_3_wound_infection': 'UInt8',
#  'diagnosis_disorder_2_CNS_mass_lesions': 'UInt8',
#  'diagnosis_disorder_2_CNS_tumors': 'UInt8',
#  'diagnosis_disorder_2_GI_bleeding_/_PUD': 'UInt8',
#  'diagnosis_disorder_2_GI_infections': 'UInt8',
#  'diagnosis_disorder_2_GI_tumors': 'UInt8',
#  'diagnosis_disorder_2_GU_infections': 'UInt8',
#  'diagnosis_disorder_2_abdominal/_general': 'UInt8',
#  'diagnosis_disorder_2_abnormality_of_urine_quantity_or_quality': 'UInt8',
#  'diagnosis_disorder_2_acute_cardiac_problems': 'UInt8',
#  'diagnosis_disorder_2_adrenal_disorders': 'UInt8',
#  'diagnosis_disorder_2_altered_mental_status_/_pain': 'UInt8',
#  'diagnosis_disorder_2_arrhythmias': 'UInt8',
#  'diagnosis_disorder_2_bleeding_and_red_blood_cell_disorders': 'UInt8',
#  'diagnosis_disorder_2_cardiac_arrest': 'UInt8',
#  'diagnosis_disorder_2_cardiac_surgery': 'UInt8',
#  'diagnosis_disorder_2_chest/pulmonary_infections': 'UInt8',
#  'diagnosis_disorder_2_chest_pain_/_ASHD': 'UInt8',
#  'diagnosis_disorder_2_chest_tumors': 'UInt8',
#  'diagnosis_disorder_2_coagulation_disorders': 'UInt8',
#  'diagnosis_disorder_2_dermatology': 'UInt8',
#  'diagnosis_disorder_2_disorder_of_acid_base': 'UInt8',
#  'diagnosis_disorder_2_disorder_of_kidney': 'UInt8',
#  'diagnosis_disorder_2_disorder_of_urinary_tract_/_renal_system_infection': 'UInt8',
#  'diagnosis_disorder_2_disorders_of_acid_base': 'UInt8',
#  'diagnosis_disorder_2_disorders_of_lung_parenchyma': 'UInt8',
#  'diagnosis_disorder_2_disorders_of_the_airways': 'UInt8',
#  'diagnosis_disorder_2_disorders_of_vasculature': 'UInt8',
#  'diagnosis_disorder_2_drug_overdose': 'UInt8',
#  'diagnosis_disorder_2_drug_withdrawal': 'UInt8',
#  'diagnosis_disorder_2_electrolyte_imbalance': 'UInt8',
#  'diagnosis_disorder_2_esophageal_disease': 'UInt8',
#  'diagnosis_disorder_2_fluid_imbalance': 'UInt8',
#  'diagnosis_disorder_2_fluids_and_electrolytes': 'UInt8',
#  'diagnosis_disorder_2_general_surgery_postop_issues': 'UInt8',
#  'diagnosis_disorder_2_glucose_metabolism': 'UInt8',
#  'diagnosis_disorder_2_hepatic_disease': 'UInt8',
#  'diagnosis_disorder_2_infections': 'UInt8',
#  'diagnosis_disorder_2_intestinal_disease': 'UInt8',
#  'diagnosis_disorder_2_malnutrition': 'UInt8',
#  'diagnosis_disorder_2_misc': 'UInt8',
#  'diagnosis_disorder_2_neurosurgical_issues': 'UInt8',
#  'diagnosis_disorder_2_other_syndromes': 'UInt8',
#  'diagnosis_disorder_2_pancreatic_disease': 'UInt8',
#  'diagnosis_disorder_2_pericardial_diseases': 'UInt8',
#  'diagnosis_disorder_2_platelet_disorders': 'UInt8',
#  'diagnosis_disorder_2_pleural_disorders': 'UInt8',
#  'diagnosis_disorder_2_post-GI_surgery': 'UInt8',
#  'diagnosis_disorder_2_post-neurosurgery': 'UInt8',
#  'diagnosis_disorder_2_post_vascular_surgery': 'UInt8',
#  'diagnosis_disorder_2_pulmonary_infections': 'UInt8',
#  'diagnosis_disorder_2_renal_issues': 'UInt8',
#  'diagnosis_disorder_2_respiratory_failure': 'UInt8',
#  'diagnosis_disorder_2_seizures': 'UInt8',
#  'diagnosis_disorder_2_shock_/_hypotension': 'UInt8',
#  'diagnosis_disorder_2_skin_and_bone_and_joint_infections': 'UInt8',
#  'diagnosis_disorder_2_systemic/other_infections': 'UInt8',
#  'diagnosis_disorder_2_thoracic_surgery': 'UInt8',
#  'diagnosis_disorder_2_thyroid': 'UInt8',
#  'diagnosis_disorder_2_trauma': 'UInt8',
#  'diagnosis_disorder_2_trauma_-_CNS': 'UInt8',
#  'diagnosis_disorder_2_trauma_-_chest': 'UInt8',
#  'diagnosis_disorder_2_trauma_-_skeletal': 'UInt8',
#  'diagnosis_disorder_2_trauma_-_systemic_effects': 'UInt8',
#  'diagnosis_disorder_2_valvular_disease': 'UInt8',
#  'diagnosis_disorder_2_vascular_disorders': 'UInt8',
#  'diagnosis_disorder_2_vascular_surgery': 'UInt8',
#  'diagnosis_disorder_2_ventricular_disorders': 'UInt8',
#  'diagnosis_disorder_2_white_blood_cell_disorders': 'UInt8',
#  'diagnosis_type_1_burns/trauma': 'UInt8',
#  'diagnosis_type_1_cardiovascular': 'UInt8',
#  'diagnosis_type_1_endocrine': 'UInt8',
#  'diagnosis_type_1_gastrointestinal': 'UInt8',
#  'diagnosis_type_1_general': 'UInt8',
#  'diagnosis_type_1_hematology': 'UInt8',
#  'diagnosis_type_1_infectious_diseases': 'UInt8',
#  'diagnosis_type_1_neurologic': 'UInt8',
#  'diagnosis_type_1_oncology': 'UInt8',
#  'diagnosis_type_1_pulmonary': 'UInt8',
#  'diagnosis_type_1_renal': 'UInt8',
#  'diagnosis_type_1_surgery': 'UInt8',
#  'diagnosis_type_1_toxicology': 'UInt8',
#  'dialysis_output': 'float32',
#  'drug_dosage': 'float32',
#  'drug_unit_APP': 'UInt8',
#  'drug_unit_APPLY': 'UInt8',
#  'drug_unit_CAP': 'UInt8',
#  'drug_unit_Cap': 'UInt8',
#  'drug_unit_Charge': 'UInt8',
#  'drug_unit_DOSE': 'UInt8',
#  'drug_unit_DROP': 'UInt8',
#  'drug_unit_Drop': 'UInt8',
#  'drug_unit_EA': 'UInt8',
#  'drug_unit_EACH': 'UInt8',
#  'drug_unit_ENEMA': 'UInt8',
#  'drug_unit_Each': 'UInt8',
#  'drug_unit_G': 'UInt8',
#  'drug_unit_GM': 'UInt8',
#  'drug_unit_Gm': 'UInt8',
#  'drug_unit_Gram': 'UInt8',
#  'drug_unit_MCG': 'UInt8',
#  'drug_unit_MEQ': 'UInt8',
#  'drug_unit_MG': 'UInt8',
#  'drug_unit_ML': 'UInt8',
#  'drug_unit_MMOL': 'UInt8',
#  'drug_unit_PACKET': 'UInt8',
#  'drug_unit_PATCH': 'UInt8',
#  'drug_unit_PUFF': 'UInt8',
#  'drug_unit_Packet': 'UInt8',
#  'drug_unit_Patch': 'UInt8',
#  'drug_unit_Puff': 'UInt8',
#  'drug_unit_SPRAY': 'UInt8',
#  'drug_unit_Spray': 'UInt8',
#  'drug_unit_TAB': 'UInt8',
#  'drug_unit_TABLET': 'UInt8',
#  'drug_unit_Tab': 'UInt8',
#  'drug_unit_Tablet': 'UInt8',
#  'drug_unit_UNIT': 'UInt8',
#  'drug_unit_UNITS': 'UInt8',
#  'drug_unit_Unit': 'UInt8',
#  'drug_unit_Units': 'UInt8',
#  'drug_unit_Units/kg': 'UInt8',
#  'drug_unit_VL': 'UInt8',
#  'drug_unit_ZZ': 'UInt8',
#  'drug_unit_app': 'UInt8',
#  'drug_unit_application': 'UInt8',
#  'drug_unit_apply': 'UInt8',
#  'drug_unit_cap(s)': 'UInt8',
#  'drug_unit_dose(s)': 'UInt8',
#  'drug_unit_drop': 'UInt8',
#  'drug_unit_drops': 'UInt8',
#  'drug_unit_each': 'UInt8',
#  'drug_unit_enema': 'UInt8',
#  'drug_unit_g': 'UInt8',
#  'drug_unit_gm': 'UInt8',
#  'drug_unit_inch(es)': 'UInt8',
#  'drug_unit_mEq': 'UInt8',
#  'drug_unit_mL': 'UInt8',
#  'drug_unit_mL/hr': 'UInt8',
#  'drug_unit_mM': 'UInt8',
#  'drug_unit_mcg': 'UInt8',
#  'drug_unit_mcg/hr': 'UInt8',
#  'drug_unit_mcg/kg': 'UInt8',
#  'drug_unit_mcg/kg/min': 'UInt8',
#  'drug_unit_mg': 'UInt8',
#  'drug_unit_mg/hr': 'UInt8',
#  'drug_unit_mg/kg': 'UInt8',
#  'drug_unit_mg/min': 'UInt8',
#  'drug_unit_microgram': 'UInt8',
#  'drug_unit_ml': 'UInt8',
#  'drug_unit_mmol': 'UInt8',
#  'drug_unit_packet': 'UInt8',
#  'drug_unit_paste': 'UInt8',
#  'drug_unit_patch': 'UInt8',
#  'drug_unit_puff': 'UInt8',
#  'drug_unit_puff(s)': 'UInt8',
#  'drug_unit_puffs': 'UInt8',
#  'drug_unit_spray': 'UInt8',
#  'drug_unit_sprays': 'UInt8',
#  'drug_unit_suppository_(ies)': 'UInt8',
#  'drug_unit_tab': 'UInt8',
#  'drug_unit_tab(s)': 'UInt8',
#  'drug_unit_tablet': 'UInt8',
#  'drug_unit_tablet(s)_/_capsule(s)': 'UInt8',
#  'drug_unit_unit(s)': 'UInt8',
#  'drug_unit_units': 'UInt8',
#  'drugadmitfrequency_.Q24H': 'UInt8',
#  'drugadmitfrequency_.STK-MED': 'UInt8',
#  'drugadmitfrequency_0': 'UInt8',
#  'drugadmitfrequency_0600_and1400_and2200': 'UInt8',
#  'drugadmitfrequency_0900': 'UInt8',
#  'drugadmitfrequency_0900_and2100': 'UInt8',
#  'drugadmitfrequency_12H': 'UInt8',
#  'drugadmitfrequency_1X': 'UInt8',
#  'drugadmitfrequency_1XONLY': 'UInt8',
#  'drugadmitfrequency_1xDaily': 'UInt8',
#  'drugadmitfrequency_1xDaily_hs': 'UInt8',
#  'drugadmitfrequency_2100': 'UInt8',
#  'drugadmitfrequency_2_Times_Daily': 'UInt8',
#  'drugadmitfrequency_2_times_daily': 'UInt8',
#  'drugadmitfrequency_2_times_per_day': 'UInt8',
#  'drugadmitfrequency_2xDaily': 'UInt8',
#  'drugadmitfrequency_3_times_daily': 'UInt8',
#  'drugadmitfrequency_3xDaily': 'UInt8',
#  'drugadmitfrequency_4x_Daily': 'UInt8',
#  'drugadmitfrequency_4x_Daily_AC_&_HS': 'UInt8',
#  'drugadmitfrequency_AS-DIR': 'UInt8',
#  'drugadmitfrequency_As_needed': 'UInt8',
#  'drugadmitfrequency_BEDTIME': 'UInt8',
#  'drugadmitfrequency_BID': 'UInt8',
#  'drugadmitfrequency_BID0600': 'UInt8',
#  'drugadmitfrequency_BIDMEAL': 'UInt8',
#  'drugadmitfrequency_BIDMEALS': 'UInt8',
#  'drugadmitfrequency_BIDWM': 'UInt8',
#  'drugadmitfrequency_BID_(09_17)': 'UInt8',
#  'drugadmitfrequency_BID_(NON-STD)': 'UInt8',
#  'drugadmitfrequency_BID_7_hour': 'UInt8',
#  'drugadmitfrequency_BID_AC': 'UInt8',
#  'drugadmitfrequency_BID_M/E': 'UInt8',
#  'drugadmitfrequency_BID_M/N': 'UInt8',
#  'drugadmitfrequency_BID_Meals': 'UInt8',
#  'drugadmitfrequency_BID_PRN': 'UInt8',
#  'drugadmitfrequency_BID_WC': 'UInt8',
#  'drugadmitfrequency_BID_X2': 'UInt8',
#  'drugadmitfrequency_CONTINUOUS': 'UInt8',
#  'drugadmitfrequency_CONT_INF': 'UInt8',
#  'drugadmitfrequency_Continuous': 'UInt8',
#  'drugadmitfrequency_Continuous_PRN': 'UInt8',
#  'drugadmitfrequency_Continuous_TPN': 'UInt8',
#  'drugadmitfrequency_DAILY': 'UInt8',
#  'drugadmitfrequency_DAILYPRN': 'UInt8',
#  'drugadmitfrequency_DAILY_(0900)': 'UInt8',
#  'drugadmitfrequency_DAILY_(1700)': 'UInt8',
#  'drugadmitfrequency_DAILY_AC': 'UInt8',
#  'drugadmitfrequency_DAILY_PM': 'UInt8',
#  'drugadmitfrequency_DAILY_PRN': 'UInt8',
#  'drugadmitfrequency_DIALYSIS_X99': 'UInt8',
#  'drugadmitfrequency_DRIP': 'UInt8',
#  'drugadmitfrequency_Daily': 'UInt8',
#  'drugadmitfrequency_Daily_BEDTIME': 'UInt8',
#  'drugadmitfrequency_Daily_Breakfast': 'UInt8',
#  'drugadmitfrequency_Daily_EARLY': 'UInt8',
#  'drugadmitfrequency_Daily_LATE': 'UInt8',
#  'drugadmitfrequency_Daily_PRN': 'UInt8',
#  'drugadmitfrequency_Daily_X3': 'UInt8',
#  'drugadmitfrequency_Daily_as_needed': 'UInt8',
#  'drugadmitfrequency_Daily_with_breakfast': 'UInt8',
#  'drugadmitfrequency_Every_12_hours': 'UInt8',
#  'drugadmitfrequency_Every_12_hours_scheduled': 'UInt8',
#  'drugadmitfrequency_Every_24_hours': 'UInt8',
#  'drugadmitfrequency_Every_2_hours_PRN': 'UInt8',
#  'drugadmitfrequency_Every_4_Hours_PRN': 'UInt8',
#  'drugadmitfrequency_Every_4_hours_PRN': 'UInt8',
#  'drugadmitfrequency_Every_5_min_PRN': 'UInt8',
#  'drugadmitfrequency_Every_6_Hours_PRN': 'UInt8',
#  'drugadmitfrequency_Every_6_hours': 'UInt8',
#  'drugadmitfrequency_Every_6_hours_PRN': 'UInt8',
#  'drugadmitfrequency_Every_8_hours': 'UInt8',
#  'drugadmitfrequency_Every_8_hours_scheduled': 'UInt8',
#  'drugadmitfrequency_GIVE_IN_PREOP/OR_X1': 'UInt8',
#  'drugadmitfrequency_HS': 'UInt8',
#  'drugadmitfrequency_HSPRN': 'UInt8',
#  'drugadmitfrequency_HS_PRN': 'UInt8',
#  'drugadmitfrequency_INFUSE': 'UInt8',
#  'drugadmitfrequency_Intra-Proc_Once_X1': 'UInt8',
#  'drugadmitfrequency_NIGHTLY': 'UInt8',
#  'drugadmitfrequency_NOW': 'UInt8',
#  'drugadmitfrequency_NOW:_for_1_dose(s)': 'UInt8',
#  'drugadmitfrequency_Nightly': 'UInt8',
#  'drugadmitfrequency_Nightly_PRN': 'UInt8',
#  'drugadmitfrequency_ONCALL': 'UInt8',
#  'drugadmitfrequency_ONCALL_X1': 'UInt8',
#  'drugadmitfrequency_ONCALL_X2': 'UInt8',
#  'drugadmitfrequency_ONCE': 'UInt8',
#  'drugadmitfrequency_ONCE:_for_1_dose(s)': 'UInt8',
#  'drugadmitfrequency_ONCERX': 'UInt8',
#  'drugadmitfrequency_ONCE_M479': 'UInt8',
#  'drugadmitfrequency_ONCE_PRN_INDEF': 'UInt8',
#  'drugadmitfrequency_ONCE_X1': 'UInt8',
#  'drugadmitfrequency_ONE': 'UInt8',
#  'drugadmitfrequency_ONETIME': 'UInt8',
#  'drugadmitfrequency_ONE_TIME': 'UInt8',
#  'drugadmitfrequency_ONE_TIME_(WARFARIN)_X1': 'UInt8',
#  'drugadmitfrequency_ONE_TIME_One_Time': 'UInt8',
#  'drugadmitfrequency_ONE_TIME_X1': 'UInt8',
#  'drugadmitfrequency_OT': 'UInt8',
#  'drugadmitfrequency_OTO': 'UInt8',
#  'drugadmitfrequency_Once': 'UInt8',
#  'drugadmitfrequency_Once_H2': 'UInt8',
#  'drugadmitfrequency_Once_PRN': 'UInt8',
#  'drugadmitfrequency_Once_PRN_X1': 'UInt8',
#  'drugadmitfrequency_Once_X1': 'UInt8',
#  'drugadmitfrequency_One_Time_Stat': 'UInt8',
#  'drugadmitfrequency_PACU_USE_ONLY': 'UInt8',
#  'drugadmitfrequency_PACU_USE_ONLY_X1': 'UInt8',
#  'drugadmitfrequency_PER_PROTOCOL': 'UInt8',
#  'drugadmitfrequency_POSTOP': 'UInt8',
#  'drugadmitfrequency_PRN': 'UInt8',
#  'drugadmitfrequency_PRNP': 'UInt8',
#  'drugadmitfrequency_PRN_X1': 'UInt8',
#  'drugadmitfrequency_PRN_X2': 'UInt8',
#  'drugadmitfrequency_PRN_X999': 'UInt8',
#  'drugadmitfrequency_PYX1TIME': 'UInt8',
#  'drugadmitfrequency_Post-Proc_Once_PRN_X1': 'UInt8',
#  'drugadmitfrequency_Pre-Proc_Once_X1': 'UInt8',
#  'drugadmitfrequency_PreOP': 'UInt8',
#  'drugadmitfrequency_Q0600': 'UInt8',
#  'drugadmitfrequency_Q12H': 'UInt8',
#  'drugadmitfrequency_Q12HR': 'UInt8',
#  'drugadmitfrequency_Q12H_(int)': 'UInt8',
#  'drugadmitfrequency_Q12H_PRN': 'UInt8',
#  'drugadmitfrequency_Q12H_SCH': 'UInt8',
#  'drugadmitfrequency_Q15MINPRN': 'UInt8',
#  'drugadmitfrequency_Q1700': 'UInt8',
#  'drugadmitfrequency_Q1H': 'UInt8',
#  'drugadmitfrequency_Q1HPRN': 'UInt8',
#  'drugadmitfrequency_Q1H_PRN': 'UInt8',
#  'drugadmitfrequency_Q1H_X2': 'UInt8',
#  'drugadmitfrequency_Q1H_X3': 'UInt8',
#  'drugadmitfrequency_Q24H': 'UInt8',
#  'drugadmitfrequency_Q24HR': 'UInt8',
#  'drugadmitfrequency_Q24H_PRN': 'UInt8',
#  'drugadmitfrequency_Q2H': 'UInt8',
#  'drugadmitfrequency_Q2HP': 'UInt8',
#  'drugadmitfrequency_Q2HPRN': 'UInt8',
#  'drugadmitfrequency_Q2H_PRN': 'UInt8',
#  'drugadmitfrequency_Q30MIN': 'UInt8',
#  'drugadmitfrequency_Q3H': 'UInt8',
#  'drugadmitfrequency_Q3HPRN': 'UInt8',
#  'drugadmitfrequency_Q3H_PRN': 'UInt8',
#  'drugadmitfrequency_Q48H': 'UInt8',
#  'drugadmitfrequency_Q4H': 'UInt8',
#  'drugadmitfrequency_Q4HP': 'UInt8',
#  'drugadmitfrequency_Q4HPRN': 'UInt8',
#  'drugadmitfrequency_Q4HR': 'UInt8',
#  'drugadmitfrequency_Q4H_LIMITED_(00;04;12;16)': 'UInt8',
#  'drugadmitfrequency_Q4H_PRN': 'UInt8',
#  'drugadmitfrequency_Q5MIN': 'UInt8',
#  'drugadmitfrequency_Q5MIN_X5': 'UInt8',
#  'drugadmitfrequency_Q5_Min_PRN': 'UInt8',
#  'drugadmitfrequency_Q6H': 'UInt8',
#  'drugadmitfrequency_Q6HP': 'UInt8',
#  'drugadmitfrequency_Q6HPRN': 'UInt8',
#  'drugadmitfrequency_Q6HR': 'UInt8',
#  'drugadmitfrequency_Q6H_PRN': 'UInt8',
#  'drugadmitfrequency_Q6H_SCH': 'UInt8',
#  'drugadmitfrequency_Q72H': 'UInt8',
#  'drugadmitfrequency_Q8H': 'UInt8',
#  'drugadmitfrequency_Q8HPRN': 'UInt8',
#  'drugadmitfrequency_Q8HR': 'UInt8',
#  'drugadmitfrequency_Q8H_(int)': 'UInt8',
#  'drugadmitfrequency_Q8H_PRN': 'UInt8',
#  'drugadmitfrequency_Q8H_SCH': 'UInt8',
#  'drugadmitfrequency_Q8H_X15': 'UInt8',
#  'drugadmitfrequency_QAM': 'UInt8',
#  'drugadmitfrequency_QAM_AC': 'UInt8',
#  'drugadmitfrequency_QDAY': 'UInt8',
#  'drugadmitfrequency_QDP': 'UInt8',
#  'drugadmitfrequency_QHS': 'UInt8',
#  'drugadmitfrequency_QHS_(2100)': 'UInt8',
#  'drugadmitfrequency_QHS_PRN': 'UInt8',
#  'drugadmitfrequency_QID': 'UInt8',
#  'drugadmitfrequency_QPM': 'UInt8',
#  'drugadmitfrequency_QPM-2000_X1': 'UInt8',
#  'drugadmitfrequency_RQ6': 'UInt8',
#  'drugadmitfrequency_RSPQ4H': 'UInt8',
#  'drugadmitfrequency_RSPQ6H': 'UInt8',
#  'drugadmitfrequency_Resp_q_1_hour_PRN': 'UInt8',
#  'drugadmitfrequency_Resp_q_4_h_PRN': 'UInt8',
#  'drugadmitfrequency_Resp_q_4_hour': 'UInt8',
#  'drugadmitfrequency_Resp_q_6_hour': 'UInt8',
#  'drugadmitfrequency_STAT': 'UInt8',
#  'drugadmitfrequency_See_Admin_Instructions_PRN': 'UInt8',
#  'drugadmitfrequency_See_Admin_Notes': 'UInt8',
#  'drugadmitfrequency_TID': 'UInt8',
#  'drugadmitfrequency_TID_(09_14_21)': 'UInt8',
#  'drugadmitfrequency_TID_AC': 'UInt8',
#  'drugadmitfrequency_TID_PRN': 'UInt8',
#  'drugadmitfrequency_TID_WC': 'UInt8',
#  'drugadmitfrequency_TITRATE': 'UInt8',
#  'drugadmitfrequency_TPN1800': 'UInt8',
#  'drugadmitfrequency_TPN_Continuous': 'UInt8',
#  'drugadmitfrequency_Titrate': 'UInt8',
#  'drugadmitfrequency_Titrate:_fordose(s)': 'UInt8',
#  'drugadmitfrequency_Titrated': 'UInt8',
#  'drugadmitfrequency_Titrated/See_admin_instructions': 'UInt8',
#  'drugadmitfrequency_To_OR': 'UInt8',
#  'drugadmitfrequency_UDP': 'UInt8',
#  'drugadmitfrequency_Warfarin': 'UInt8',
#  'drugadmitfrequency_X1': 'UInt8',
#  'drugadmitfrequency_as_directed': 'UInt8',
#  'drugadmitfrequency_at_bedtime': 'UInt8',
#  'drugadmitfrequency_bid8_and0800_and1800_INDEF': 'UInt8',
#  'drugadmitfrequency_bid:0900_and2100_fordose(s)': 'UInt8',
#  'drugadmitfrequency_bida_and0800_and2200_INDEF': 'UInt8',
#  'drugadmitfrequency_cont:_fordose(s)': 'UInt8',
#  'drugadmitfrequency_continuous_INDEF': 'UInt8',
#  'drugadmitfrequency_daily': 'UInt8',
#  'drugadmitfrequency_daily9:0900_fordose(s)': 'UInt8',
#  'drugadmitfrequency_every_other_day': 'UInt8',
#  'drugadmitfrequency_four_times_a_day': 'UInt8',
#  'drugadmitfrequency_prn1_INDEF': 'UInt8',
#  'drugadmitfrequency_prn4_INDEF': 'UInt8',
#  'drugadmitfrequency_prn6_INDEF': 'UInt8',
#  'drugadmitfrequency_prn_INDEF': 'UInt8',
#  'drugadmitfrequency_prnqd_INDEF': 'UInt8',
#  'drugadmitfrequency_q12hr': 'UInt8',
#  'drugadmitfrequency_q12hr_(interval)': 'UInt8',
#  'drugadmitfrequency_q15minprn_INDEF': 'UInt8',
#  'drugadmitfrequency_q1hr': 'UInt8',
#  'drugadmitfrequency_q24hr_(interval)': 'UInt8',
#  'drugadmitfrequency_q2hr': 'UInt8',
#  'drugadmitfrequency_q4hprn:_fordose(s)': 'UInt8',
#  'drugadmitfrequency_q4hr': 'UInt8',
#  'drugadmitfrequency_q5min': 'UInt8',
#  'drugadmitfrequency_q5min_H4': 'UInt8',
#  'drugadmitfrequency_q6hr': 'UInt8',
#  'drugadmitfrequency_q8hr': 'UInt8',
#  'drugadmitfrequency_q8hr_(interval)': 'UInt8',
#  'drugadmitfrequency_qDay': 'UInt8',
#  'drugadmitfrequency_qHS': 'UInt8',
#  'drugadmitfrequency_q_12_hour': 'UInt8',
#  'drugadmitfrequency_q_12_hour_(BID)': 'UInt8',
#  'drugadmitfrequency_q_1_hour_PRN': 'UInt8',
#  'drugadmitfrequency_q_24_h': 'UInt8',
#  'drugadmitfrequency_q_24_hour': 'UInt8',
#  'drugadmitfrequency_q_24_hour_(daily)': 'UInt8',
#  'drugadmitfrequency_q_2_hour_PRN': 'UInt8',
#  'drugadmitfrequency_q_3_hour_PRN': 'UInt8',
#  'drugadmitfrequency_q_4_hour_PRN': 'UInt8',
#  'drugadmitfrequency_q_5_min_PRN': 'UInt8',
#  'drugadmitfrequency_q_6_hour': 'UInt8',
#  'drugadmitfrequency_q_6_hour_PRN': 'UInt8',
#  'drugadmitfrequency_q_8_hour': 'UInt8',
#  'drugadmitfrequency_q_8_hour_PRN': 'UInt8',
#  'drugadmitfrequency_qd22_and2200_INDEF': 'UInt8',
#  'drugadmitfrequency_qd8_and0800_INDEF': 'UInt8',
#  'drugadmitfrequency_three_times_a_day': 'UInt8',
#  'drugadmitfrequency_tid_and0800_and1600_and2200_INDEF': 'UInt8',
#  'drugadmitfrequency_twice_a_day': 'UInt8',
#  'drughiclseqno_10012': 'UInt8',
#  'drughiclseqno_10093': 'UInt8',
#  'drughiclseqno_10132': 'UInt8',
#  'drughiclseqno_10247': 'UInt8',
#  'drughiclseqno_10249': 'UInt8',
#  'drughiclseqno_10278': 'UInt8',
#  'drughiclseqno_10321': 'UInt8',
#  'drughiclseqno_1040': 'UInt8',
#  'drughiclseqno_10485': 'UInt8',
#  'drughiclseqno_1053': 'UInt8',
#  'drughiclseqno_1061': 'UInt8',
#  'drughiclseqno_1062': 'UInt8',
#  'drughiclseqno_10705': 'UInt8',
#  'drughiclseqno_1075': 'UInt8',
#  'drughiclseqno_1099': 'UInt8',
#  'drughiclseqno_1100': 'UInt8',
#  'drughiclseqno_11060': 'UInt8',
#  'drughiclseqno_11254': 'UInt8',
#  'drughiclseqno_113': 'UInt8',
#  'drughiclseqno_11505': 'UInt8',
#  'drughiclseqno_11528': 'UInt8',
#  'drughiclseqno_11560': 'UInt8',
#  'drughiclseqno_11582': 'UInt8',
#  'drughiclseqno_11595': 'UInt8',
#  'drughiclseqno_1163': 'UInt8',
#  'drughiclseqno_1168': 'UInt8',
#  'drughiclseqno_11735': 'UInt8',
#  'drughiclseqno_11792': 'UInt8',
#  'drughiclseqno_11814': 'UInt8',
#  'drughiclseqno_1186': 'UInt8',
#  'drughiclseqno_12014': 'UInt8',
#  'drughiclseqno_12182': 'UInt8',
#  'drughiclseqno_12204': 'UInt8',
#  'drughiclseqno_1224': 'UInt8',
#  'drughiclseqno_12259': 'UInt8',
#  'drughiclseqno_1235': 'UInt8',
#  'drughiclseqno_1236': 'UInt8',
#  'drughiclseqno_12383': 'UInt8',
#  'drughiclseqno_12384': 'UInt8',
#  'drughiclseqno_1239': 'UInt8',
#  'drughiclseqno_12404': 'UInt8',
#  'drughiclseqno_1241': 'UInt8',
#  'drughiclseqno_12779': 'UInt8',
#  'drughiclseqno_1289': 'UInt8',
#  'drughiclseqno_130': 'UInt8',
#  'drughiclseqno_1301': 'UInt8',
#  'drughiclseqno_131': 'UInt8',
#  'drughiclseqno_1319': 'UInt8',
#  'drughiclseqno_132': 'UInt8',
#  'drughiclseqno_13209': 'UInt8',
#  'drughiclseqno_13237': 'UInt8',
#  'drughiclseqno_1324': 'UInt8',
#  'drughiclseqno_1326': 'UInt8',
#  'drughiclseqno_1329': 'UInt8',
#  'drughiclseqno_1330': 'UInt8',
#  'drughiclseqno_13449': 'UInt8',
#  'drughiclseqno_13455': 'UInt8',
#  'drughiclseqno_136': 'UInt8',
#  'drughiclseqno_1370': 'UInt8',
#  'drughiclseqno_13778': 'UInt8',
#  'drughiclseqno_13795': 'UInt8',
#  'drughiclseqno_13864': 'UInt8',
#  'drughiclseqno_13894': 'UInt8',
#  'drughiclseqno_1396': 'UInt8',
#  'drughiclseqno_14015': 'UInt8',
#  'drughiclseqno_14772': 'UInt8',
#  'drughiclseqno_14777': 'UInt8',
#  'drughiclseqno_14778': 'UInt8',
#  'drughiclseqno_1478': 'UInt8',
#  'drughiclseqno_150': 'UInt8',
#  'drughiclseqno_1554': 'UInt8',
#  'drughiclseqno_159': 'UInt8',
#  'drughiclseqno_15908': 'UInt8',
#  'drughiclseqno_1592': 'UInt8',
#  'drughiclseqno_1608': 'UInt8',
#  'drughiclseqno_1610': 'UInt8',
#  'drughiclseqno_1615': 'UInt8',
#  'drughiclseqno_1617': 'UInt8',
#  'drughiclseqno_1619': 'UInt8',
#  'drughiclseqno_1620': 'UInt8',
#  'drughiclseqno_1628': 'UInt8',
#  'drughiclseqno_1629': 'UInt8',
#  'drughiclseqno_1643': 'UInt8',
#  'drughiclseqno_1644': 'UInt8',
#  'drughiclseqno_1650': 'UInt8',
#  'drughiclseqno_1652': 'UInt8',
#  'drughiclseqno_1653': 'UInt8',
#  'drughiclseqno_1655': 'UInt8',
#  'drughiclseqno_1661': 'UInt8',
#  'drughiclseqno_16911': 'UInt8',
#  'drughiclseqno_1694': 'UInt8',
#  'drughiclseqno_1695': 'UInt8',
#  'drughiclseqno_1730': 'UInt8',
#  'drughiclseqno_1741': 'UInt8',
#  'drughiclseqno_1742': 'UInt8',
#  'drughiclseqno_1745': 'UInt8',
#  'drughiclseqno_17539': 'UInt8',
#  'drughiclseqno_17791': 'UInt8',
#  'drughiclseqno_17876': 'UInt8',
#  'drughiclseqno_1794': 'UInt8',
#  'drughiclseqno_180': 'UInt8',
#  'drughiclseqno_18047': 'UInt8',
#  'drughiclseqno_18084': 'UInt8',
#  'drughiclseqno_181': 'UInt8',
#  'drughiclseqno_182': 'UInt8',
#  'drughiclseqno_1820': 'UInt8',
#  'drughiclseqno_183': 'UInt8',
#  'drughiclseqno_1848': 'UInt8',
#  'drughiclseqno_1854': 'UInt8',
#  'drughiclseqno_1866': 'UInt8',
#  'drughiclseqno_1874': 'UInt8',
#  'drughiclseqno_1877': 'UInt8',
#  'drughiclseqno_1882': 'UInt8',
#  'drughiclseqno_1884': 'UInt8',
#  'drughiclseqno_189': 'UInt8',
#  'drughiclseqno_1893': 'UInt8',
#  'drughiclseqno_1894': 'UInt8',
#  'drughiclseqno_18979': 'UInt8',
#  'drughiclseqno_1898': 'UInt8',
#  'drughiclseqno_1905': 'UInt8',
#  'drughiclseqno_19058': 'UInt8',
#  'drughiclseqno_19078': 'UInt8',
#  'drughiclseqno_1929': 'UInt8',
#  'drughiclseqno_1944': 'UInt8',
#  'drughiclseqno_1948': 'UInt8',
#  'drughiclseqno_1949': 'UInt8',
#  'drughiclseqno_1950': 'UInt8',
#  'drughiclseqno_1975': 'UInt8',
#  'drughiclseqno_1988': 'UInt8',
#  'drughiclseqno_19963': 'UInt8',
#  'drughiclseqno_2004': 'UInt8',
#  'drughiclseqno_2028': 'UInt8',
#  'drughiclseqno_20292': 'UInt8',
#  'drughiclseqno_20401': 'UInt8',
#  'drughiclseqno_2045': 'UInt8',
#  'drughiclseqno_2048': 'UInt8',
#  'drughiclseqno_2050': 'UInt8',
#  'drughiclseqno_2051': 'UInt8',
#  'drughiclseqno_2059': 'UInt8',
#  'drughiclseqno_20607': 'UInt8',
#  'drughiclseqno_2073': 'UInt8',
#  'drughiclseqno_2074': 'UInt8',
#  'drughiclseqno_20769': 'UInt8',
#  'drughiclseqno_2084': 'UInt8',
#  'drughiclseqno_2087': 'UInt8',
#  'drughiclseqno_2095': 'UInt8',
#  'drughiclseqno_20952': 'UInt8',
#  'drughiclseqno_20968': 'UInt8',
#  'drughiclseqno_20971': 'UInt8',
#  'drughiclseqno_20974': 'UInt8',
#  'drughiclseqno_2101': 'UInt8',
#  'drughiclseqno_2102': 'UInt8',
#  'drughiclseqno_2103': 'UInt8',
#  'drughiclseqno_2104': 'UInt8',
#  'drughiclseqno_21157': 'UInt8',
#  'drughiclseqno_2148': 'UInt8',
#  'drughiclseqno_21607': 'UInt8',
#  'drughiclseqno_21772': 'UInt8',
#  'drughiclseqno_21773': 'UInt8',
#  'drughiclseqno_21974': 'UInt8',
#  'drughiclseqno_21993': 'UInt8',
#  'drughiclseqno_22008': 'UInt8',
#  'drughiclseqno_22025': 'UInt8',
#  'drughiclseqno_22033': 'UInt8',
#  'drughiclseqno_223': 'UInt8',
#  'drughiclseqno_22819': 'UInt8',
#  'drughiclseqno_22961': 'UInt8',
#  'drughiclseqno_24022': 'UInt8',
#  'drughiclseqno_24024': 'UInt8',
#  'drughiclseqno_24459': 'UInt8',
#  'drughiclseqno_24551': 'UInt8',
#  'drughiclseqno_25009': 'UInt8',
#  'drughiclseqno_25040': 'UInt8',
#  'drughiclseqno_25056': 'UInt8',
#  'drughiclseqno_25277': 'UInt8',
#  'drughiclseqno_25281': 'UInt8',
#  'drughiclseqno_25386': 'UInt8',
#  'drughiclseqno_25998': 'UInt8',
#  'drughiclseqno_26407': 'UInt8',
#  'drughiclseqno_26470': 'UInt8',
#  'drughiclseqno_26521': 'UInt8',
#  'drughiclseqno_26698': 'UInt8',
#  'drughiclseqno_271': 'UInt8',
#  'drughiclseqno_2728': 'UInt8',
#  'drughiclseqno_2749': 'UInt8',
#  'drughiclseqno_2766': 'UInt8',
#  'drughiclseqno_2769': 'UInt8',
#  'drughiclseqno_2793': 'UInt8',
#  'drughiclseqno_2803': 'UInt8',
#  'drughiclseqno_2810': 'UInt8',
#  'drughiclseqno_2812': 'UInt8',
#  'drughiclseqno_2816': 'UInt8',
#  'drughiclseqno_2826': 'UInt8',
#  'drughiclseqno_2839': 'UInt8',
#  'drughiclseqno_2849': 'UInt8',
#  'drughiclseqno_2866': 'UInt8',
#  'drughiclseqno_2867': 'UInt8',
#  'drughiclseqno_2876': 'UInt8',
#  'drughiclseqno_2879': 'UInt8',
#  'drughiclseqno_2888': 'UInt8',
#  'drughiclseqno_2889': 'UInt8',
#  'drughiclseqno_2899': 'UInt8',
#  'drughiclseqno_2901': 'UInt8',
#  'drughiclseqno_32690': 'UInt8',
#  'drughiclseqno_32900': 'UInt8',
#  'drughiclseqno_33094': 'UInt8',
#  'drughiclseqno_33174': 'UInt8',
#  'drughiclseqno_33191': 'UInt8',
#  'drughiclseqno_33229': 'UInt8',
#  'drughiclseqno_33243': 'UInt8',
#  'drughiclseqno_33314': 'UInt8',
#  'drughiclseqno_33347': 'UInt8',
#  'drughiclseqno_33461': 'UInt8',
#  'drughiclseqno_33592': 'UInt8',
#  'drughiclseqno_33598': 'UInt8',
#  'drughiclseqno_33904': 'UInt8',
#  'drughiclseqno_34106': 'UInt8',
#  'drughiclseqno_34126': 'UInt8',
#  'drughiclseqno_34344': 'UInt8',
#  'drughiclseqno_34632': 'UInt8',
#  'drughiclseqno_34756': 'UInt8',
#  'drughiclseqno_34805': 'UInt8',
#  'drughiclseqno_34908': 'UInt8',
#  'drughiclseqno_35085': 'UInt8',
#  'drughiclseqno_35262': 'UInt8',
#  'drughiclseqno_35779': 'UInt8',
#  'drughiclseqno_35915': 'UInt8',
#  'drughiclseqno_36020': 'UInt8',
#  'drughiclseqno_36156': 'UInt8',
#  'drughiclseqno_3635': 'UInt8',
#  'drughiclseqno_3649': 'UInt8',
#  'drughiclseqno_36550': 'UInt8',
#  'drughiclseqno_3660': 'UInt8',
#  'drughiclseqno_3662': 'UInt8',
#  'drughiclseqno_3663': 'UInt8',
#  'drughiclseqno_3664': 'UInt8',
#  'drughiclseqno_3672': 'UInt8',
#  'drughiclseqno_36808': 'UInt8',
#  'drughiclseqno_36875': 'UInt8',
#  'drughiclseqno_36921': 'UInt8',
#  'drughiclseqno_37109': 'UInt8',
#  'drughiclseqno_37123': 'UInt8',
#  'drughiclseqno_3717': 'UInt8',
#  'drughiclseqno_37207': 'UInt8',
#  'drughiclseqno_3723': 'UInt8',
#  'drughiclseqno_3727': 'UInt8',
#  'drughiclseqno_37328': 'UInt8',
#  'drughiclseqno_37356': 'UInt8',
#  'drughiclseqno_3744': 'UInt8',
#  'drughiclseqno_37442': 'UInt8',
#  'drughiclseqno_37458': 'UInt8',
#  'drughiclseqno_37678': 'UInt8',
#  'drughiclseqno_3792': 'UInt8',
#  'drughiclseqno_3794': 'UInt8',
#  'drughiclseqno_38448': 'UInt8',
#  'drughiclseqno_3976': 'UInt8',
#  'drughiclseqno_3996': 'UInt8',
#  'drughiclseqno_4': 'UInt8',
#  'drughiclseqno_4013': 'UInt8',
#  'drughiclseqno_4042': 'UInt8',
#  'drughiclseqno_4053': 'UInt8',
#  'drughiclseqno_4071': 'UInt8',
#  'drughiclseqno_4124': 'UInt8',
#  'drughiclseqno_4129': 'UInt8',
#  'drughiclseqno_4132': 'UInt8',
#  'drughiclseqno_4157': 'UInt8',
#  'drughiclseqno_4183': 'UInt8',
#  'drughiclseqno_4212': 'UInt8',
#  'drughiclseqno_4297': 'UInt8',
#  'drughiclseqno_4480': 'UInt8',
#  'drughiclseqno_4519': 'UInt8',
#  'drughiclseqno_4520': 'UInt8',
#  'drughiclseqno_4521': 'UInt8',
#  'drughiclseqno_4673': 'UInt8',
#  'drughiclseqno_4703': 'UInt8',
#  'drughiclseqno_4704': 'UInt8',
#  'drughiclseqno_4763': 'UInt8',
#  'drughiclseqno_4791': 'UInt8',
#  'drughiclseqno_4834': 'UInt8',
#  'drughiclseqno_4842': 'UInt8',
#  'drughiclseqno_4846': 'UInt8',
#  'drughiclseqno_4868': 'UInt8',
#  'drughiclseqno_4884': 'UInt8',
#  'drughiclseqno_517': 'UInt8',
#  'drughiclseqno_5175': 'UInt8',
#  'drughiclseqno_5225': 'UInt8',
#  'drughiclseqno_523': 'UInt8',
#  'drughiclseqno_525': 'UInt8',
#  'drughiclseqno_532': 'UInt8',
#  'drughiclseqno_538': 'UInt8',
#  'drughiclseqno_540': 'UInt8',
#  'drughiclseqno_549': 'UInt8',
#  'drughiclseqno_551': 'UInt8',
#  'drughiclseqno_553': 'UInt8',
#  'drughiclseqno_57': 'UInt8',
#  'drughiclseqno_581': 'UInt8',
#  'drughiclseqno_582': 'UInt8',
#  'drughiclseqno_585': 'UInt8',
#  'drughiclseqno_5859': 'UInt8',
#  'drughiclseqno_5900': 'UInt8',
#  'drughiclseqno_6031': 'UInt8',
#  'drughiclseqno_6055': 'UInt8',
#  'drughiclseqno_6071': 'UInt8',
#  'drughiclseqno_609': 'UInt8',
#  ...}

# %% [markdown]
# ## Exploring the cleaned dataset

# %% [markdown]
# ### Loading the data

# %%
eICU_df = du.data_processing.load_chunked_data(file_name='eICU', data_path=data_path, 
                                               dtypes=dtype_dict, ordered_naming=False)
eICU_df.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))

# %% [markdown]
# ### Basic stuff

# %%
eICU_df.dtypes

# %%
eICU_df.nunique()

# %%
du.search_explore.dataframe_missing_values(eICU_df)

# %%
eICU_df.describe().transpose()

# %% [markdown]
# Number of model features:

# %%
len(eICU_df.columns) - 3

# %% [markdown]
# Number of data points (# features x # rows):

# %%
len(eICU_df.columns) * len(eICU_df)

# %% [markdown]
# ### Label analysis

# %% [markdown]
# Counting the samples with positive label:

# %%
label_count = eICU_df.niv_label.value_counts()
label_count

# %%
print(f'{(label_count[True] / (label_count[True] + label_count[False])) * 100}%')

# %% [markdown]
# How many subjects always have the same label in their time series:

# %%
const_label_subj = list()
for subject in eICU_df.subject_id.unique():
    subject_data = eICU_df[eICU_df.subject_id == subject]
    if subject_data.niv_label.min() == subject_data.niv_label.max():
        const_label_subj.append(subject)
const_label_subj

# %%
len(const_label_subj)

# %%
percent_const_label_subj = (len(const_label_subj) / eICU_df.subject_id.nunique()) * 100
print(f'{percent_const_label_subj}%')

# %% [markdown]
# ### Time / sampling variation

# %%
eICU_df['delta_ts'] = eICU_df.groupby('subject_id').ts.diff()
eICU_df.head()

# %%
eICU_df.delta_ts.describe()

# %% [markdown]
# ### Sequence length analysis

# %%
seq_len = eICU_df.groupby('subject_id').ts.count()
seq_len.head()

# %%
seq_len.describe()

# %% [markdown]
# ### Plots

# %%
ALS_proc_gender_count = ALS_proc_df.groupby('subject_id').first().gender.value_counts().to_frame()
data = [go.Pie(labels=ALS_proc_gender_count.index, values=ALS_proc_gender_count.gender)]
layout = go.Layout(title='Patients Gender Demographics')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Histogram(x = orig_ALS_df.groupby('subject_id').first().age_at_onset)]
layout = go.Layout(title='Patient age distribution')
fig = go.Figure(data, layout)
fig.show()

# %%
ALS_proc_niv_count = ALS_proc_df.niv.value_counts().to_frame()
data = [go.Pie(labels=ALS_proc_niv_count.index, values=ALS_proc_niv_count.niv)]
layout = go.Layout(title='Visits where the patient is using NIV')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Histogram(x = ALS_proc_df.niv)]
layout = go.Layout(title='Number of visits where the patient is using NIV')
fig = go.Figure(data, layout)
fig.show()

# %%
ALS_proc_patient_niv_count = ALS_proc_df.groupby('subject_id').niv.max().value_counts().to_frame()
data = [go.Pie(labels=ALS_proc_patient_niv_count.index, values=ALS_proc_patient_niv_count.niv)]
layout = go.Layout(title='Patients which eventually use NIV')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Scatter(
                    x = ALS_proc_df.fvc,
                    y = ALS_proc_df.niv,
                    mode = 'markers'
                  )]
layout = go.Layout(
                    title='Relation between NIV use and FVC values',
                    xaxis=dict(title='FVC'),
                    yaxis=dict(title='NIV')
                  )
fig = go.Figure(data, layout)
fig.show()

# %%
# Average FVC value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1].fvc.mean()

# %% [markdown]
# **Comments:** The average FVC when NIV is 1 is lower than average, but the scatter plot doesn't show a very clear dependence between the variables.

# %%
data = [go.Scatter(
                    x = ALS_proc_df['disease_duration'],
                    y = ALS_proc_df.niv,
                    mode = 'markers'
                  )]
layout = go.Layout(
                    title='Relation between NIV use and disease duration',
                    xaxis=dict(title='Disease duration'),
                    yaxis=dict(title='NIV')
                  )
fig = go.Figure(data, layout)
fig.show()

# %%
# Average disease duration when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['disease_duration'].mean()

# %%
data = [go.Scatter(
                    x = ALS_proc_df['age_at_onset'],
                    y = ALS_proc_df.niv,
                    mode = 'markers'
                  )]
layout = go.Layout(
                    title='Relation between NIV use and age',
                    xaxis=dict(title='Age at onset'),
                    yaxis=dict(title='NIV')
                  )
fig = go.Figure(data, layout)
fig.show()

# %%
# Average age at onset when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['age_at_onset'].mean()

# %%
ALS_proc_NIV_3R = ALS_proc_df.groupby(['3r', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_proc_NIV_3R[ALS_proc_NIV_3R.niv == 0]['3r'],
                    y=ALS_proc_NIV_3R[ALS_proc_NIV_3R.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_proc_NIV_3R[ALS_proc_NIV_3R.niv == 1]['3r'],
                    y=ALS_proc_NIV_3R[ALS_proc_NIV_3R.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and normalized 3R', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
ALS_NIV_3R = orig_ALS_df.groupby(['3r', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_NIV_3R[ALS_NIV_3R.niv == 0]['3r'],
                    y=ALS_NIV_3R[ALS_NIV_3R.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_NIV_3R[ALS_NIV_3R.niv == 1]['3r'],
                    y=ALS_NIV_3R[ALS_NIV_3R.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and 3R', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
# Average 3R value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['3r'].mean()

# %% [markdown]
# **Comments:** Clearly, there's a big dependence of the use of NIV with the respiratory symptoms indicated by 3R, as expected.

# %%
data = [go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 0].p10, name='Not used'),
        go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 1].p10, name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and normalized P10.')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 0].p10, name='Not used'),
        go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 1].p10, name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and P10.')
fig = go.Figure(data, layout)
fig.show()

# %%
# Average P10 value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['p10'].mean()

# %% [markdown]
# **Comments:** Clearly, there's a big dependence of the use of NIV with the respiratory symptoms indicated by P10, as expected.

# %%
ALS_proc_NIV_R = ALS_proc_df.groupby(['r', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_proc_NIV_R[ALS_proc_NIV_R.niv == 0]['r'],
                    y=ALS_proc_NIV_R[ALS_proc_NIV_R.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_proc_NIV_R[ALS_proc_NIV_R.niv == 1]['r'],
                    y=ALS_proc_NIV_R[ALS_proc_NIV_R.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and normalized R', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
ALS_NIV_R = orig_ALS_df.groupby(['r', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_NIV_R[ALS_NIV_R.niv == 0]['r'],
                    y=ALS_NIV_R[ALS_NIV_R.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_NIV_R[ALS_NIV_R.niv == 1]['r'],
                    y=ALS_NIV_R[ALS_NIV_R.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and R', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
# Average R value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['r'].mean()

# %% [markdown]
# **Comments:** There seems to be a relationship between the use of NIV and the respiratory symptoms indicated by R, as expected.

# %%
data = [go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 0].bmi, name='Not used'),
        go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 1].bmi, name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and normalized BMI.')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 0].bmi, name='Not used'),
        go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 1].bmi, name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and BMI.')
fig = go.Figure(data, layout)
fig.show()

# %%
# Average BMI value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['bmi'].mean()

# %% [markdown]
# **Comments:** There is no clear, universal relationship between the use of NIV and BMI.

# %%
ALS_proc_NIV_p5 = ALS_proc_df.groupby(['p5', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_proc_NIV_p5[ALS_proc_NIV_p5.niv == 0]['p5'],
                    y=ALS_proc_NIV_p5[ALS_proc_NIV_p5.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_proc_NIV_p5[ALS_proc_NIV_p5.niv == 1]['p5'],
                    y=ALS_proc_NIV_p5[ALS_proc_NIV_p5.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and normalized P5', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
ALS_NIV_p5 = orig_ALS_df.groupby(['p5', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_NIV_p5[ALS_NIV_p5.niv == 0]['p5'],
                    y=ALS_NIV_p5[ALS_NIV_p5.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_NIV_p5[ALS_NIV_p5.niv == 1]['p5'],
                    y=ALS_NIV_p5[ALS_NIV_p5.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and P5', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
# Average P5 value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['p5'].mean()

# %% [markdown]
# **Comments:** There seems to be a relationship between the use of NIV and the strength symptoms indicated by P5.

# %%
ALS_proc_NIV_P4 = ALS_proc_df.groupby(['p4', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_proc_NIV_P4[ALS_proc_NIV_P4.niv == 0]['p4'],
                    y=ALS_proc_NIV_P4[ALS_proc_NIV_P4.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_proc_NIV_P4[ALS_proc_NIV_P4.niv == 1]['p4'],
                    y=ALS_proc_NIV_P4[ALS_proc_NIV_P4.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and normalized P4', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
ALS_NIV_P4 = orig_ALS_df.groupby(['p4', 'niv']).subject_id.count().to_frame().reset_index()
data = [go.Bar(
                    x=ALS_NIV_P4[ALS_NIV_P4.niv == 0]['p4'],
                    y=ALS_NIV_P4[ALS_NIV_P4.niv == 0]['subject_id'],
                    name='Not used'
              ),
        go.Bar(
                    x=ALS_NIV_P4[ALS_NIV_P4.niv == 1]['p4'],
                    y=ALS_NIV_P4[ALS_NIV_P4.niv == 1]['subject_id'],
                    name='Using NIV'
        )]
layout = go.Layout(title='Relation between NIV use and P4', barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
# Average P4 value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['p4'].mean()

# %% [markdown]
# **Comments:** There seems to be a relationship between the use of NIV and the handwriting symptoms indicated by P4.

# %%
data = [go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 0]['p0.1'], name='Not used'),
        go.Histogram(x = ALS_proc_df[ALS_proc_df.niv == 1]['p0.1'], name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and normalized P0.1.')
fig = go.Figure(data, layout)
fig.show()

# %%
data = [go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 0]['p0.1'], name='Not used'),
        go.Histogram(x = orig_ALS_df[orig_ALS_df.niv == 1]['p0.1'], name='Using NIV')]
layout = go.Layout(title='Relation between NIV use and P0.1.')
fig = go.Figure(data, layout)
fig.show()

# %%
# Average P0.1 value when NIV is used:
ALS_proc_df[ALS_proc_df.niv == 1]['p0.1'].mean()

# %% [markdown]
# **Comments:** There is no clear, universal relationship between the use of NIV and P0.1.
